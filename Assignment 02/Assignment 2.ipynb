# %% [markdown]
# # Assignment 2

# %% [markdown]
# Fill in the blank values using countif-sumif

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Formulae for Exercise 1:
#
# count and countifs :
#
# 1.number of orders in Boston :=COUNTIF(G2:G25,"Boston")
#
# 2.number of microwave orders  :=COUNTIF(D2:D25,"microwave")
#
# 3.number of journeys with truck 3 :=COUNTIF(F2:F25,"truck 3")
#
# 4.number of Peter White journeys:=COUNTIF(C2:C25, "Peter White")
#
# 5.how many times are no. of items less than 20: =COUNTIF(E2:E25, "<20")
#
#
# Sumif and Sumifs
#
# 6.sum of refrigerator items:=SUMIF(D2:D25,"refrigerator",E2:E25)
#
# 7.sum of washing machine items:=SUMIF(D2:D25, "washing machine",E2:E25)
#
# 8.sum of items transported by truck 4:=SUMIF(F2:F25, "truck 4", E2:E25)
#
# 9.sum of items transported by trucks:=SUMIF(F2:F25,"*truck*",E2:E25)
#
#
# countif
#
# 10.number of microvawe orders in Boston :=COUNTIFS(D2:D25,"microwave",G2:G25,"Boston")
#
# 11.number of Peter White journeys with truck 1:=COUNTIFS(C2:C25,"Peter White",F2:F25,"truck 1")
#
# 12.number of orders in Boston after 2/3/2013:=COUNTIFS(B2:B25,">03-02-2013",G2:G25, "Boston")
#
# 13.number of orders between 2/3/2013 and 2/6/2013:=COUNTIFS(B2:B25,">03-02-13",B2:B25,"<06-02-13")
#
#
# countifs
#
# 14.sum of microwaves transported to NY:=SUMIFS(E2:E25,D2:D25,"microwave",G2:G25,"NY")
#
# 15.sum of items transported to Pittsburgh by truck 1:=SUMIFS(E2:E25,G2:G25,"Pittsburgh",F2:F25,"truck 1")
#
# 16.sum of items ordered between 2/3/2013 and 2/6/2013:=SUMIFS(E2:E25,B2:B25,">03-02-13",B2:B25,"<06-02-13")
#
#
# sumifs
#
# 17.sum of items transported to NY, Baltimore and Philadelphia:=SUMIF(G2:G25,"NY",E2:E25)+SUMIF(G2:G25,"Baltimore",E2:E25)+SUMIF(G2:G25,"Philadelphia",E2:E25)

# %% [markdown]
# Formulae for Exercise 2:
#
#  Table No 1
#
# 1.Shaving:
#
# 1.How many times total:=COUNTIF(B16:B241,A2)
#
# 2.Total price :=SUMIF(B16:B241,A2,E16:E241)
#
# 3.How many times by cash :=COUNTIFS(D16:D241,"cash",B16:B241,A2)
#
# 4.How many times by credit card:=COUNTIFS(D16:D241,"credit card",B6:B241,A2)
#
# 5.Total price by cash :=SUMIFS(E16:E241,D16:D241,"cash",B16:B241,A2)
#
#
#
# 2.Washing and combing:
#
#
# 1.How many times total:=COUNTIF(B16:B241,A3)
#
# 2.Total price :=SUMIF(B16:B241,A3,E16:E241)
#
# 3.How many times by cash :=COUNTIFS(D16:D241,"cash",B16:B241,A3)
#
# 4.How many times by credit card:=COUNTIFS(D16:D241,"credit card",B16:B241,A3)
#
# 5.Total price by cash :=SUMIFS(E16:E241,D16:D241,"cash",B16:B241,A3)
#
#
# 3.Dyeing:
#
#
# 1.How many times total:=COUNTIF(B16:B241,A4)
#
# 2.Total price :=SUMIF(B16:B241,A4,E16:E241)
#
# 3.How many times by cash :=COUNTIFS(D16:D241,"cash",B16:B241,A4)
#
# 4.How many times by credit card:=COUNTIFS(D16:D241,"credit card",B16:B241,A4)
#
# 5.Total price by cash :=SUMIFS(E16:E241,D16:D241,"cash",B16:B241,A4)
#
#
# 4.Meeting hairstyles:
#
#
# 1.How many times total:=COUNTIF(B6:G241,A5)
#
# 2.Total price :=SUMIF(B16:B241,A5,E16:E241)
#
# 3.How many times by cash :=COUNTIFS(D16:D241,"cash",B16:B241,A5)
#
# 4.How many times by credit card:=COUNTIFS(D16:D241,"credit card",B16:B241,A5)
#
# 5.Total price by cash :=SUMIFS(E16:E241,D16:D241,"cash",B16:B241,A5)
#
#
# Table No 2
#
#
# 1.Jane
#
#
# 1.How many times total =COUNTIF(C16:C241,A9)
#
# 2.Total price =SUMIF(C16:C241,A9,E16:E241)
#
# 3.How many times Shaving =COUNTIFS(B16:B241,"Shaving",C16:C241,A9)
#
# 4.How many times Kids =COUNTIFS(B16:B241,"Kids",C16:C241,A9)
#
# 5.Sum of price for Shaving between 5/10/2013 and 5/20/2013 =SUMIFS(E16:E241,A16:A241,"<10-05-2013",A16:A241,">20-05-2013")
#
#
#
# 2.Martha
#
#
#
# 1.How many times total =COUNTIF(C16:C241,A10)
#
# 2.Total price =SUMIF(C16:C241,A10,E16:E241)
#
# 3.How many times Shaving =COUNTIFS(B16:B241,"Shaving",C16:C241,A10)
#
# 4.How many times Kids =COUNTIFS(B16:B241,"Kids",C16:C241,A10)
#
# 5.Sum of price for Shaving between 5/10/2013 and 5/20/2013 =SUMIFS(E16:E241,A16:A241,"<10-05-2013",A16:A241,">20-05-2013")
#
#
#
# 3.Alex
#
#
# 1.How many times total =COUNTIF(C16:C241,A11)
#
# 2.Total price =SUMIF(C16:C241,A11,E16:E241)
#
# 3.How many times Shaving =COUNTIFS(B16:B241,"Shaving",C16:C241,A11)
#
# 4.How many times Kids =COUNTIFS(B16:B241,"Kids",C16:C241,A11)
#
# 5.Sum of price for Shaving between 5/10/2013 and 5/20/2013 =SUMIFS(E16:E241,A16:A241,"<10-05-2013",A16:A241,">20-05-2013")
