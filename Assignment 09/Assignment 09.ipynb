# %% [markdown]
# # Assignment 9:

# %% [markdown]
# 1.Find the maximum and minimum and sum of all the radiation amounts.
#
# maximaum : =MAX(A2:A41)
#
# minium : =MIN(A2:A41)
#
# sum :=SUM(A2:A41)

# %% [markdown]
# 3.Find the count and Rank:
#
# Count : =COUNT(A2:A41)
#
# rank : =RANK(A2,$A$2:$A$41) ## drag and drop
#
#
# 4.Compute the mean and standard deviation of the radiation amounts:
#
# mean:=AVERAGE(A2:A41)
#
# standard deviation:=STDEV.P(A2:A41)
#
#
# 5.Describe a certain objective a researcher might have had in mind when collecting this data:
#
# To analyze data for future  and To gain useful information that can be necessary To provide higher and lower points as well as average data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
