# %% [markdown]
# # Assignment 3

# %% [markdown]
# Copy of Find-Duplicates-and-Show-the-Count

# %% [markdown]
# There are Two seperate methods:
#
# 1.use this formulae and drag and drop in columns away from table:
#
#
# =LEFT(SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2),FIND("%",SUBSTITUTE(IF(ISNUMBER(FIND("(",A2)),SUBSTITUTE(A2,"("," "),SUBSTITUTE(A2&"-","-","%"))," ","%",2))-1)
#
#
# Then  use ,
#
#
#
# =IF(COUNTIF($E$1:E2,E2)=1,COUNTIF(E:E,E2),"")
#
#
#  in to COUNT columns and drag and drop.
#
#
#
# 2.Use Separate formulae into boxes:
#
#
#     1.=COUNTIF(A2:A19,"FDR-*")
#
#
#     2.=COUNTIFS(A2:A19,"Server Room-*",A2:A19,"<>*Door*")
#
#
#     3.=COUNTIFS(A2:A19,"Server Room-*",A2:A19,"*Door*")
#
#
#     4.=COUNTIF(A2:A19,"MUX*")
#
#
#     5.=COUNTIF(A2:A19,"UPS Room*")
#
#
#     6.=COUNTIF(A2:A19,"Battery Bank*")
#
#
#     7.=COUNTIF(A2:A19,"BMS")
#
#
#     8.=COUNTIF(A2:A19,"Electrical Room*")
#
#
#     9.=COUNTIF(A2:A19,"Panel Room-*")
#
#
# obviously, Second one is more lengthy So we can use first one .

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
